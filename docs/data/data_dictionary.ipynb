# %% [markdown]
# # **Diccionario de los datos**
# ---

# %% [markdown]
# ## **Descripción de la base de datos**
# La base de datos cuenta con un total de 1311 registros y 44 variables. A continuación se realiza la descripción de las variables que tendrán en cuenta para el estudio.

# %%
# Subir base de datos arabiga_data_cleaned
# Librerías requeridas
import pandas as pd

# %%
variables = pd.read_excel('variables.xlsx')
variables
# Out:
#         Variables Variable_español         Tipo
# 0           Aroma            Aroma     numérica
# 1          Flavor            Sabor     numérica
# 2      Aftertaste       Retrosabor     numérica
# 3         Acidity           Acidez     numérica
# 4            Body           Cuerpo     numérica
# 5         Balance      Uniformidad     numérica
# 6       Clean Cup      Taza limpia     numérica
# 7       Sweetness           Dulzor     numérica
# 8   Cupper points   Puntos de taza     numérica
# 9         Country             País  cualitativa
# 10        Variety         Variedad  Cualitativa
# 11           Type             Tipo  Cualitativa
# 12         Points        Puntos        numérica
# 13       Moisture          Humedad     numérica
