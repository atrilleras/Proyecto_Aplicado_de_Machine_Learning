# %% [markdown]
# # **Definición de los datos**
# ---

# %% [markdown]
# ## **Origen de los datos**
#
# Los datos en los que se basa el presete estudio corresponde a los
# registros de variedades de café del Instituto de la Calidad del Café (CQI), la cual
# es una institución fundada en 1996 y tiene como misión la de trabajar constantemente en la mejora de la calidad del café y de la vida de las personas que lo producen. Para el CQI la calidad es una de las variables más importantes que influyen en el valor de un café. Sin embargo, muchos
# productores no tienen acceso a las herramientas y el apoyo que necesitan para
# comprender la calidad de su café, mejorar esa calidad, acceder a mercados que
# recompensan esa calidad y, en última instancia, les permiten tomar decisiones
# comerciales más informadas. Ahí es donde radica el protagonismo de esta institución.

# %% [markdown]
# ## **Scripts para la carga de los datos**
# Para llevar a cabo el cargue de la base de datos, se debe realizar el siguiente procedimiento:
# 1. Subir al entorno de colab la base de datos definida por *arabiga_data_cleaned* que corresponde a un archivo en formato CSV.
# 2. Implementar el siguiente código para acceder a la información de la base de datos.

# %%
# Subir base de datos arabiga_data_cleaned
# Librerías requeridas
import pandas as pd

# %%
# Cargar el archivo CSV
df = pd.read_csv('arabica_data_cleaned.csv')
df.head(4)
# Out:
#    Unnamed: 0  Species                     Owner Country.of.Origin  \
# 0           1  Arabica                 metad plc          Ethiopia
# 1           2  Arabica                 metad plc          Ethiopia
# 2           3  Arabica  grounds for health admin         Guatemala
# 3           4  Arabica       yidnekachew dabessa          Ethiopia
#
#                                   Farm.Name Lot.Number       Mill ICO.Number  \
# 0                                 metad plc        NaN  metad plc  2014/2015
# 1                                 metad plc        NaN  metad plc  2014/2015
# 2  san marcos barrancas "san cristobal cuch        NaN        NaN        NaN
# 3     yidnekachew dabessa coffee plantation        NaN    wolensu        NaN
#
#                                  Company       Altitude  ...  Color  \
# 0      metad agricultural developmet plc      1950-2200  ...  Green
# 1      metad agricultural developmet plc      1950-2200  ...  Green
# ...

# %% [markdown]
# ## **Ruta de acceso a los datos**
# Para acceder a los datos de origen se puede dirigir al link [coffee-quality-database](https://github.com/jldbc/coffee-quality-database/tree/master/data).
